# %% [markdown]
# <a href="https://colab.research.google.com/github/menaelharany862006-creator/flyrank-ml-yourname/blob/main/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/menaelharany862006-creator/flyrank-ml-yourname/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# I choose the Refresh / Content Opportunity Scoring lane. I already ran the starter pipeline in Weeks 1-2 and saw a learned model beat a hand-written rule at flagging declining pages (Precision@50 went from 0.240 to 0.740). I want to build on this by improving how we decide which pages the content team should review first, using only real search signals already in the dataset.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Decision: Which pages should the content team review and refresh first, given limited time? Action: A content editor opens the ranked list and updates the top pages. Cost of a wrong call: If we flag a healthy page, we waste editor time on something that didn't need fixing. If we miss a real decliner, the page keeps losing visibility while no one notices.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# I loaded the starter dataset directly to check how many pages are realistic review candidates before committing 7 weeks to this lane.

# %%
import os, subprocess
REPO_DIR = "flyrank-ml-yourname"
subprocess.run(["git", "clone", "--depth", "1", "https://github.com/menaelharany862006-creator/flyrank-ml-yourname", REPO_DIR])
os.chdir(REPO_DIR)

import pandas as pd
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

declining_rate = (df["trend_direction"] == "down").mean()
stale_visible = df[(df["days_since_last_update"] >= 180) & (df["impressions_90d"] >= 500)]

print(f"Total pages: {len(df):,}")
print(f"Declining pages (trend_direction == 'down'): {declining_rate:.1%}")
print(f"Stale + visible pages (real review candidates): {len(stale_visible):,} ({len(stale_visible)/len(df):.1%} of all pages)")
# Out:
# Total pages: 30,000
# Declining pages (trend_direction == 'down'): 54.2%
# Stale + visible pages (real review candidates): 17 (0.1% of all pages)

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This work can say: "these pages show observed signals of decline" and "this ranking is directional evidence for where to look first." It cannot say: "refreshing these pages will cause traffic to recover" or "this predicts Google's algorithm." Success will be measured as an improvement in Precision@K over the baseline rule, validated with a client-holdout split — not a guarantee of real-world results.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under work/notebooks/ — then submit your repo URL on the card. Done.
